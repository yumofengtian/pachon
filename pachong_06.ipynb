# %%
import urllib.request
import urllib.parse
import re
import os
import time

def handle_request(url,page):
    url = url + str(page) + '/'
    #print(url)
    headers ={
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'
    }
    request = urllib.request.Request(url=url, headers=headers)
    return request

# <img src="//pic.qiushibaike.com/system/pictures/12205/122053061/medium/9OT5MKQC50LHVSZ6.jpg" alt="优秀作文赏析">
def download_image(content):
    pattern = re.compile(r'<div class="thumb">.*?<img src="(.*?)".*?>.*?</div>',re.S)
    lt = pattern.findall(content)
    # print(lt)
    # 遍历列表，依次下载图片
    for image_src in lt:
        # 先处理image_src
        image_src = 'https:' + image_src
        # 发送请求，下载图片
        # 创建文件夹
        dirname = 'qiutu'
        if not os.path.exists(dirname):
            os.mkdir(dirname)
        # 图片的名字
        filename = image_src.split('/')[-1]
        filepath = dirname + '/' + filename
        print('%s图片正在下载。。。'% filename)
        urllib.request.urlretrieve(image_src, filepath)
        print('%s图片结束下载。。。'% filename)
        time.sleep(1)
        
def main():
    url = 'https://www.qiushibaike.com/pic/page/'
    start_page = int(input('请输入起始页码：'))
    end_page = int(input('请输入结束页码：'))
    for page in range(start_page,end_page + 1):
        print('第%s页开始下载。。。。'% page)
        # 生成请求对象
        request = handle_request(url,page)
        # 发送请求对象，获取相应内容
        content = urllib.request.urlopen(request).read().decode()
        # 解析内容，提取所有的图片链接，下载图片
        download_image(content)
        print('第%s页结束下载。。。。'% page)
        time.sleep(2)
        
if __name__ == '__main__':
    main()
# Out:
# 请输入起始页码：1
# 请输入结束页码：1
# 第1页开始下载。。。。
# QZ6MZ2Q20C4TSDIA.jpg图片正在下载。。。
# QZ6MZ2Q20C4TSDIA.jpg图片结束下载。。。
# IG77OQA3EIXPCC09.jpg图片正在下载。。。
# IG77OQA3EIXPCC09.jpg图片结束下载。。。
# Q2UZ8HH22Q56O59M.jpg图片正在下载。。。
# Q2UZ8HH22Q56O59M.jpg图片结束下载。。。
# R4R4E9SNXG9CMRY6.jpg图片正在下载。。。
# R4R4E9SNXG9CMRY6.jpg图片结束下载。。。
# 5BL4XJ6T6CVG54C7.jpg图片正在下载。。。
# 5BL4XJ6T6CVG54C7.jpg图片结束下载。。。
# EYZN6QMX001NH6FB.jpg图片正在下载。。。
# EYZN6QMX001NH6FB.jpg图片结束下载。。。
# H6TEVJWNEWEBKOVP.jpg图片正在下载。。。
# H6TEVJWNEWEBKOVP.jpg图片结束下载。。。
# W6NZYAJYW22QAIU9.jpg图片正在下载。。。
# W6NZYAJYW22QAIU9.jpg图片结束下载。。。
# FKYABX24SM3H4PS3.jpg图片正在下载。。。
# FKYABX24SM3H4PS3.jpg图片结束下载。。。
# 3BV6AEPJQKKLSJA0.jpg图片正在下载。。。
# 3BV6AEPJQKKLSJA0.jpg图片结束下载。。。
# IK6BE07UZ0UWFO02.jpg图片正在下载。。。
# IK6BE07UZ0UWFO02.jpg图片结束下载。。。
# 98K8SXUZDI3F72U2.jpg图片正在下载。。。
# 98K8SXUZDI3F72U2.jpg图片结束下载。。。
# XH9D5YX01KVP37A9.jpg图片正在下载。。。
# XH9D5YX01KVP37A9.jpg图片结束下载。。。
# BEJRU2ET9LIOO31K.jpg图片正在下载。。。
# BEJRU2ET9LIOO31K.jpg图片结束下载。。。
# 2H07CNC977NW6X5G.jpg图片正在下载。。。
# 2H07CNC977NW6X5G.jpg图片结束下载。。。
# VCYEX9AQVVH0T8YD.jpg图片正在下载。。。
# VCYEX9AQVVH0T8YD.jpg图片结束下载。。。
# 2WFTGX6IUMMDESU6.jpg图片正在下载。。。
# 2WFTGX6IUMMDESU6.jpg图片结束下载。。。
# RUQWEKQBKRIH0F13.jpg图片正在下载。。。
# RUQWEKQBKRIH0F13.jpg图片结束下载。。。
# DY1S2BXCIX08X1AT.jpg图片正在下载。。。
# DY1S2BXCIX08X1AT.jpg图片结束下载。。。
# XPEGSRJO1N7L7D8X.jpg图片正在下载。。。
# XPEGSRJO1N7L7D8X.jpg图片结束下载。。。
# 第1页结束下载。。。。
